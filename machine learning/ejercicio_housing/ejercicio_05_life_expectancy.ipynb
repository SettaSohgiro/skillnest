# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler



df = pd.read_csv("data/life_expectancy.csv")

display(df.head())
display(df.tail())
display(df.info())
display(df.describe())
# Out:
#        CountryYear  Status  Life expectancy  Adult Mortality  infant deaths  \
# 0  Afghanistan2015       0             65.0              263             62
# 1  Afghanistan2014       0             59.9              271             64
# 2  Afghanistan2013       0             59.9              268             66
# 3  Afghanistan2012       0             59.5              272             69
# 4  Afghanistan2011       0             59.2              275             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   BMI  ...  Polio  \
# 0     0.01               71.279624         65.0     1154  19.1  ...    6.0
# 1     0.01               73.523582         62.0      492  18.6  ...   58.0
# 2     0.01               73.219243         64.0      430  18.1  ...   62.0
# 3     0.01               78.184215         67.0     2787  17.6  ...   67.0
# 4     0.01                7.097109         68.0     3013  17.2  ...   68.0
#
# ...

# %%
# print(df.isnull().sum())

# df = pd.read_csv('data/life_expectancy.csv', index_col='CountryYear').dropna()

# X = df.drop(columns=['Life expectancy','Status'])
# y = df['Life expectancy']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# scaler = StandardScaler()
# X_train_esc = scaler.fit_transform(X_train)
# X_test_esc = scaler.transform(X_test)

# print(f"Media de la primera columna de x_train : {X_train_esc[:,0].mean():.4f}")
# print(f"Media de la primera columna de x_train : {X_train_esc[:,0].std():.4f}")


df = pd.read_csv('data/life_expectancy.csv', index_col='CountryYear').dropna()
X = df.drop(columns=['Life expectancy', 'Status'])
y = df['Life expectancy']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

scaler = StandardScaler()
X_train_esc = scaler.fit_transform(X_train)
X_test_esc  = scaler.transform(X_test)
life =  scaler.fit_transform(df[['Life expectancy']])



print(f'Media de la primera columna en train: {X_train_esc[:,0].mean():.4f}')
print(f'Desv  de la primera columna en train: {X_train_esc[:,0].std():.4f}')

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].hist(df['Life expectancy'], bins=30); axes[0].set_title('Antes')
axes[1].hist(X_train_esc, bins=30, color='red'); axes[1].set_title('Después')
plt.show()
# Out:
# Media de la primera columna en train: -0.0000
# Desv  de la primera columna en train: 1.0000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 33
#      29 print(f'Desv  de la primera columna en train: {X_train_esc[:,0].std():.4f}')
#      30
#      31 fig, axes = plt.subplots(1, 2, figsize=(12, 4))
#      32 axes[0].hist(df['Life expectancy'], bins=30); axes[0].set_title('Antes')
# ---> 33 axes[1].hist(X_train_esc, bins=30, color='red'); axes[1].set_title('Después')
#      34 plt.show()
#
# File c:\Users\lquel\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
# ...
